# %%
#ensure version 0.1.1
import littlesis
from littlesis import littlesis as ls
print(littlesis.__version__)
# Out:
# 0.1.1

# %% [markdown]
# ### Convert from LittleSis ID to name and vice versa

# %% [markdown]
# id_to_name() evades the task of discovering which names an ID is referring to by searching through the LittleSis database. The real value of this function comes when used iteratively, as it is used throughout this package in different functions, to translate a string of ID numbers as is produced by most LittleSis API calls to the more relevant names of the individuals or organization. Similarly name_to_id() simplifies the task of searching for relevant id numbers required when performing simple get requests of your own to the site.

# %%
ls.id_to_name(1)
# Out:
# 'Walmart Inc.'

# %%
ls.name_to_id('walmart')
# Out:
# 1

# %% [markdown]
# The inverse of id_to_name

# %% [markdown]
# ### Making simple entity get request to the site, using name rather than ID

# %% [markdown]
# Unfortunately get requests to the site typically require knowledge of the ID number for an entity, but this function fixes that obstacle. With entity() users can simply type in the name of an individual or organization to get the corresponding information. View LittleSis API documentation [here](https://littlesis.org/api) to better understand what types of API calls are allowed, on which this package is based. In all of API requests to the site, and in all of this package's functions, if names aren't exactly correct as entered, or shortened to only last name for example, the function will return the one entity for that API call that has the highest number of connections within the database. For example below, entity('Obama') is equivalent to entity('Barack Obama') and entity('obama').

# %%
ls.entity('Obama')
# Out:
# {'meta': {'copyright': 'LittleSis CC BY-SA 4.0',
#   'license': 'https://creativecommons.org/licenses/by-sa/4.0/',
#   'apiVersion': '2.0'},
#  'data': {'type': 'entities',
#   'id': 13503,
#   'attributes': {'id': 13503,
#    'name': 'Barack Obama',
#    'blurb': '44th President of the United States',
#    'summary': 'The 44th President of the United States, he was sworn into office on January 20, 2009; born in Honolulu, Hawaii, August 4, 1961; obtained early education in Jakarta, Indonesia, and Hawaii; continued education at Occidental College, Los Angeles, Calif.; received a B.A. in 1983 from Columbia University, New York City; worked as a community organizer in Chicago, Ill.; studied law at Harvard University, where he became the first African American president of the Harvard Law Review, and received J.D. in 1991; lecturer on constitutional law, University of Chicago; member, Illinois State senate 1997-2004; elected as a Democrat to the U.S. Senate in 2004 for term beginning January 3, 2005.',
#    'website': 'http://obama.senate.gov/',
#    'parent_id': None,
#    'primary_ext': 'Person',
#    'updated_at': '2021-12-15T21:28:15Z',
#    'start_date': '1961-08-04',
#    'end_date': None,
#    'aliases': ['Barack Obama'],
#    'types': ['Person', 'Political Candidate', 'Elected Representative']},
#   'links': {'self': 'https://littlesis.org/entities/13503-Barack_Obama'}}}

# %% [markdown]
# ### Get entity info by name input in dataframe

# %% [markdown]
# When further data analysis is required, it's more useful to have the information from the entity get request parsed from a JSON into a pandas dataframe. Basic_entity() is a fuction crucial to the iteration performed in the list_entities() function. Basic_entity provides a dataframe for one individual or organization, while list_entities includes all listed entities in the dataframe. The LittleSis API has rate limits on API calls, so for the following functions, throttling was used using the ratelimit python package. These functions only are able to perform one API call per second.

# %%
ls.basic_entity('Obama')
# Out:
# info          name         aliases                                blurb  \
# 0     Barack Obama  [Barack Obama]  44th President of the United States
#
# info date_of_birth  end_date  \
# 0       1961-08-04       NaN
#
# info                                              types  \
# 0     [Person, Political Candidate, Elected Represen...
#
# info                   website
# 0     http://obama.senate.gov/

# %%
ls.list_entities('Obama', 'Donald Trump')
# Out:
# info          name                    aliases  \
# 0     Barack Obama             [Barack Obama]
# 1     Donald Trump  [Donald Trump, P80001571]
#
# info                                blurb date_of_birth  end_date  \
# 0     44th President of the United States    1961-08-04       NaN
# 1     45th President of the United States    1946-06-14       NaN
#
# info                                              types  \
# 0     [Person, Political Candidate, Elected Represen...
# 1        [Person, Political Candidate, Business Person]
#
# info                   website
# 0     http://obama.senate.gov/
# 1        http://www.trump.com/

# %% [markdown]
# ### Get relationships info by name input

# %% [markdown]
# Similar to entity(), relationship simplifies the task of making a type of get request to the site, specifically the relationship get request that typically requires entry of the ID number for an individual or organization. The result is a JSON, but relationships_df() below produces the corresponding pandas dataframe if that is preferred output.

# %%
ls.relationships('Obama')
# Out:
# {'meta': {'currentPage': 1,
#   'pageCount': 354,
#   'copyright': 'LittleSis CC BY-SA 4.0',
#   'license': 'https://creativecommons.org/licenses/by-sa/4.0/',
#   'apiVersion': '2.0'},
#  'data': [{'type': 'relationships',
#    'id': 1809642,
#    'attributes': {'id': 1809642,
#     'entity1_id': 284888,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 3800,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 6,
#     'updated_at': '2021-12-15T21:28:15Z',
#     'start_date': '2008-08-28',
#     'end_date': '2012-10-26',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Francis Rooney  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1809642',
#    'entity': 'https://littlesis.org/person/284888-Francis_Rooney',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1809438,
#    'attributes': {'id': 1809438,
#     'entity1_id': 76199,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 281,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2021-12-15T18:50:05Z',
#     'start_date': '2012-08-17',
#     'end_date': '2012-08-17',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'James E Risch  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1809438',
#    'entity': 'https://littlesis.org/person/76199-James_E_Risch',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1781869,
#    'attributes': {'id': 1781869,
#     'entity1_id': 400766,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 600,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2021-09-28T21:20:43Z',
#     'start_date': '2008-08-31',
#     'end_date': '2008-08-31',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Deborah Ross  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1781869',
#    'entity': 'https://littlesis.org/person/400766-Deborah_Ross',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1767384,
#    'attributes': {'id': 1767384,
#     'entity1_id': 193559,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 250,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2021-05-11T14:49:39Z',
#     'start_date': '2012-09-08',
#     'end_date': '2012-09-08',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Andrew M Bursky  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1767384',
#    'entity': 'https://littlesis.org/person/193559-Andrew_M_Bursky',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1757920,
#    'attributes': {'id': 1757920,
#     'entity1_id': 313891,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 2250,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 2,
#     'updated_at': '2021-04-02T13:40:45Z',
#     'start_date': '2012-05-24',
#     'end_date': '2012-06-15',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Patricia Ann Woertz  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1757920',
#    'entity': 'https://littlesis.org/person/313891-Patricia_Ann_Woertz',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1757890,
#    'attributes': {'id': 1757890,
#     'entity1_id': 24707,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 1000,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2021-04-02T13:39:28Z',
#     'start_date': '2012-09-10',
#     'end_date': '2012-09-10',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Mark E Goldhaber  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1757890',
#    'entity': 'https://littlesis.org/person/24707-Mark_E_Goldhaber',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1754881,
#    'attributes': {'id': 1754881,
#     'entity1_id': 10002,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 1350,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 5,
#     'updated_at': '2021-03-17T20:28:25Z',
#     'start_date': '2008-07-31',
#     'end_date': '2012-08-21',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Melvyn J Estrin  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1754881',
#    'entity': 'https://littlesis.org/person/10002-Melvyn_J_Estrin',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1754266,
#    'attributes': {'id': 1754266,
#     'entity1_id': 337029,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 500,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 2,
#     'updated_at': '2021-03-15T15:34:49Z',
#     'start_date': '2008-00-00',
#     'end_date': '2008-00-00',
#     'is_current': None,
#     'is_featured': False,
#     'description': 'Greg Stanton  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1754266',
#    'entity': 'https://littlesis.org/person/337029-Greg_Stanton',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1754242,
#    'attributes': {'id': 1754242,
#     'entity1_id': 58513,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 2750,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 2,
#     'updated_at': '2021-03-15T15:32:30Z',
#     'start_date': '2008-05-07',
#     'end_date': '2012-03-06',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Charles T Hagel  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1754242',
#    'entity': 'https://littlesis.org/person/58513-Charles_T_Hagel',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1754231,
#    'attributes': {'id': 1754231,
#     'entity1_id': 58513,
#     'entity2_id': 13503,
#     'category_id': 1,
#     'description1': 'Defense Secretary',
#     'description2': 'Defense Secretary',
#     'amount': None,
#     'currency': None,
#     'goods': None,
#     'filings': None,
#     'updated_at': '2021-03-15T15:32:20Z',
#     'start_date': None,
#     'end_date': None,
#     'is_current': None,
#     'is_featured': False,
#     'description': 'Charles T Hagel  has/had a position (Defense Secretary) at  Barack Obama ',
#     'category_attributes': {'is_board': None,
#      'is_executive': None,
#      'is_employee': None,
#      'compensation': None,
#      'boss_id': None}},
#    'self': 'https://littlesis.org/relationships/1754231',
#    'entity': 'https://littlesis.org/person/58513-Charles_T_Hagel',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1754173,
#    'attributes': {'id': 1754173,
#     'entity1_id': 248613,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 200,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2021-03-15T15:23:48Z',
#     'start_date': '2008-07-07',
#     'end_date': '2008-07-07',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Art J Gajarsa  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1754173',
#    'entity': 'https://littlesis.org/person/248613-Art_J_Gajarsa',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1752994,
#    'attributes': {'id': 1752994,
#     'entity1_id': 183284,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 2550,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 4,
#     'updated_at': '2021-03-08T20:05:21Z',
#     'start_date': '2007-03-05',
#     'end_date': '2007-05-18',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Tony West  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1752994',
#    'entity': 'https://littlesis.org/person/183284-Tony_West',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1746953,
#    'attributes': {'id': 1746953,
#     'entity1_id': 13503,
#     'entity2_id': 73685,
#     'category_id': 10,
#     'description1': None,
#     'description2': None,
#     'amount': None,
#     'currency': None,
#     'goods': None,
#     'filings': None,
#     'updated_at': '2021-01-19T01:11:01Z',
#     'start_date': None,
#     'end_date': None,
#     'is_current': None,
#     'is_featured': False,
#     'description': "Barack Obama  is/was an owner of  President's Council on Jobs and Competitiveness ",
#     'category_attributes': {'percent_stake': None, 'shares': None}},
#    'self': 'https://littlesis.org/relationships/1746953',
#    'entity': 'https://littlesis.org/person/13503-Barack_Obama',
#    'related': "https://littlesis.org/org/73685-President's_Council_on_Jobs_and_Competitiveness"},
#   {'type': 'relationships',
#    'id': 1746553,
#    'attributes': {'id': 1746553,
#     'entity1_id': 9870,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 1000,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2021-01-14T16:04:41Z',
#     'start_date': '2008-02-21',
#     'end_date': '2008-02-21',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Kimmarie Sinatra  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1746553',
#    'entity': 'https://littlesis.org/person/9870-Kimmarie_Sinatra',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1746402,
#    'attributes': {'id': 1746402,
#     'entity1_id': 42811,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 250,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2021-01-12T20:35:33Z',
#     'start_date': '2008-03-05',
#     'end_date': '2008-03-05',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'John Jacob Rhodes III  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1746402',
#    'entity': 'https://littlesis.org/person/42811-John_Jacob_Rhodes_III',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1742090,
#    'attributes': {'id': 1742090,
#     'entity1_id': 242045,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 1250,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 2,
#     'updated_at': '2020-12-14T16:20:27Z',
#     'start_date': '2008-01-31',
#     'end_date': '2008-07-29',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Louise M Sunshine  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1742090',
#    'entity': 'https://littlesis.org/person/242045-Louise_M_Sunshine',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1741815,
#    'attributes': {'id': 1741815,
#     'entity1_id': 78058,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 3250,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 5,
#     'updated_at': '2020-12-11T17:30:37Z',
#     'start_date': '2007-03-21',
#     'end_date': '2012-07-25',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Lisa E Davis  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1741815',
#    'entity': 'https://littlesis.org/person/78058-Lisa_E_Davis',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1741419,
#    'attributes': {'id': 1741419,
#     'entity1_id': 399519,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 2300,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-12-08T23:14:53Z',
#     'start_date': '2007-09-30',
#     'end_date': '2007-09-30',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Barry Weissler  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1741419',
#    'entity': 'https://littlesis.org/person/399519-Barry_Weissler',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1741384,
#    'attributes': {'id': 1741384,
#     'entity1_id': 399510,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 500,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-12-08T21:15:16Z',
#     'start_date': '2012-07-31',
#     'end_date': '2012-07-31',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Paul Stockton  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1741384',
#    'entity': 'https://littlesis.org/person/399510-Paul_Stockton',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1741016,
#    'attributes': {'id': 1741016,
#     'entity1_id': 399440,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 4850,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 5,
#     'updated_at': '2020-12-05T21:57:06Z',
#     'start_date': '2011-09-20',
#     'end_date': '2012-09-28',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Faye Fields  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1741016',
#    'entity': 'https://littlesis.org/person/399440-Faye_Fields',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1740935,
#    'attributes': {'id': 1740935,
#     'entity1_id': 228501,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 2300,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-12-05T21:03:20Z',
#     'start_date': '2008-01-18',
#     'end_date': '2008-01-18',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Katrina Peebles  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1740935',
#    'entity': 'https://littlesis.org/person/228501-Katrina_Peebles',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1740921,
#    'attributes': {'id': 1740921,
#     'entity1_id': 35140,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 2300,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-12-05T21:00:37Z',
#     'start_date': '2008-01-18',
#     'end_date': '2008-01-18',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'R Donahue Peebles  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1740921',
#    'entity': 'https://littlesis.org/person/35140-R_Donahue_Peebles',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 531834,
#    'attributes': {'id': 531834,
#     'entity1_id': 15862,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': -2100,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 3,
#     'updated_at': '2020-12-04T14:56:41Z',
#     'start_date': '2008-00-00',
#     'end_date': '2012-00-00',
#     'is_current': None,
#     'is_featured': False,
#     'description': 'David M Marchick  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/531834',
#    'entity': 'https://littlesis.org/person/15862-David_M_Marchick',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1740702,
#    'attributes': {'id': 1740702,
#     'entity1_id': 399353,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 5000,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 2,
#     'updated_at': '2020-12-03T19:25:20Z',
#     'start_date': '2011-10-19',
#     'end_date': '2011-10-19',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Gloria Getty  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1740702',
#    'entity': 'https://littlesis.org/person/399353-Gloria_Getty',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1740417,
#    'attributes': {'id': 1740417,
#     'entity1_id': 313800,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 500,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-11-30T17:44:09Z',
#     'start_date': '2011-11-25',
#     'end_date': '2011-11-25',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Joel M Wine  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1740417',
#    'entity': 'https://littlesis.org/person/313800-Joel_M_Wine',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1740065,
#    'attributes': {'id': 1740065,
#     'entity1_id': 189530,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 1150,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 3,
#     'updated_at': '2020-11-30T00:03:38Z',
#     'start_date': '2012-05-21',
#     'end_date': '2012-10-31',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Raphael W Bostic  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1740065',
#    'entity': 'https://littlesis.org/person/189530-Raphael_W_Bostic',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 471859,
#    'attributes': {'id': 471859,
#     'entity1_id': 104018,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 35800,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 3,
#     'updated_at': '2020-11-27T16:52:25Z',
#     'start_date': '2008-00-00',
#     'end_date': '2012-04-10',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Tillie Klearman Walton  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/471859',
#    'entity': 'https://littlesis.org/person/104018-Tillie_Klearman_Walton',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 771880,
#    'attributes': {'id': 771880,
#     'entity1_id': 49914,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 5000,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 2,
#     'updated_at': '2020-11-27T16:50:50Z',
#     'start_date': '2008-00-00',
#     'end_date': '2012-04-10',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Sam Rawlings Walton  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/771880',
#    'entity': 'https://littlesis.org/person/49914-Sam_Rawlings_Walton',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 857540,
#    'attributes': {'id': 857540,
#     'entity1_id': 170588,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 8000,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 3,
#     'updated_at': '2020-11-26T21:47:52Z',
#     'start_date': '2008-00-00',
#     'end_date': '2011-05-02',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Reuben Munger  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/857540',
#    'entity': 'https://littlesis.org/person/170588-Reuben_Munger',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1739433,
#    'attributes': {'id': 1739433,
#     'entity1_id': 398948,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 7300,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 6,
#     'updated_at': '2020-11-26T21:43:59Z',
#     'start_date': '2008-09-04',
#     'end_date': '2012-08-31',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Sage Weil  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1739433',
#    'entity': 'https://littlesis.org/person/398948-Sage_Weil',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1125875,
#    'attributes': {'id': 1125875,
#     'entity1_id': 230688,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 10560,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 8,
#     'updated_at': '2020-11-26T20:59:15Z',
#     'start_date': '2007-00-00',
#     'end_date': '2012-09-21',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Merle Chambers  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1125875',
#    'entity': 'https://littlesis.org/person/230688-Merle_Chambers',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1738797,
#    'attributes': {'id': 1738797,
#     'entity1_id': 71607,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 300,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-11-24T15:50:12Z',
#     'start_date': '2012-03-30',
#     'end_date': '2012-03-30',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'David N Dinkins  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1738797',
#    'entity': 'https://littlesis.org/person/71607-David_N_Dinkins',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 806712,
#    'attributes': {'id': 806712,
#     'entity1_id': 35341,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 800,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 2,
#     'updated_at': '2020-11-23T19:19:28Z',
#     'start_date': '2012-00-00',
#     'end_date': '2012-11-03',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Tony Blinken  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/806712',
#    'entity': 'https://littlesis.org/person/35341-Tony_Blinken',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1738209,
#    'attributes': {'id': 1738209,
#     'entity1_id': 398578,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 250,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-11-20T14:59:17Z',
#     'start_date': '2008-09-30',
#     'end_date': '2008-09-30',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Kenneth M Rosenberg  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1738209',
#    'entity': 'https://littlesis.org/person/398578-Kenneth_M_Rosenberg',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1737846,
#    'attributes': {'id': 1737846,
#     'entity1_id': 35502,
#     'entity2_id': 13503,
#     'category_id': 1,
#     'description1': 'Foreign Policy Advisor To',
#     'description2': None,
#     'amount': None,
#     'currency': None,
#     'goods': None,
#     'filings': None,
#     'updated_at': '2020-11-19T00:47:14Z',
#     'start_date': None,
#     'end_date': None,
#     'is_current': None,
#     'is_featured': False,
#     'description': 'Anthony Lake  has/had a position (Foreign Policy Advisor To) at  Barack Obama ',
#     'category_attributes': {'is_board': None,
#      'is_executive': None,
#      'is_employee': None,
#      'compensation': None,
#      'boss_id': None}},
#    'self': 'https://littlesis.org/relationships/1737846',
#    'entity': 'https://littlesis.org/person/35502-Anthony_Lake',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1737776,
#    'attributes': {'id': 1737776,
#     'entity1_id': 117374,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 303,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-11-18T19:08:35Z',
#     'start_date': '2008-09-30',
#     'end_date': '2008-09-30',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Kathy Boockvar  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1737776',
#    'entity': 'https://littlesis.org/person/117374-Kathy_Boockvar',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 394322,
#    'attributes': {'id': 394322,
#     'entity1_id': 92237,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 4500,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 6,
#     'updated_at': '2020-11-17T17:14:48Z',
#     'start_date': '2007-00-00',
#     'end_date': '2012-10-25',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Janet Yang  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/394322',
#    'entity': 'https://littlesis.org/person/92237-Janet_Yang',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1737154,
#    'attributes': {'id': 1737154,
#     'entity1_id': 314386,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 9500,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 5,
#     'updated_at': '2020-11-15T23:08:35Z',
#     'start_date': '2007-09-19',
#     'end_date': '2012-04-20',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Sharon Zackfia  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1737154',
#    'entity': 'https://littlesis.org/person/314386-Sharon_Zackfia',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1736887,
#    'attributes': {'id': 1736887,
#     'entity1_id': 398022,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 2300,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-11-14T19:02:38Z',
#     'start_date': '2008-07-22',
#     'end_date': '2008-07-22',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Melanie Franco Nussdorf  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1736887',
#    'entity': 'https://littlesis.org/person/398022-Melanie_Franco_Nussdorf',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1736835,
#    'attributes': {'id': 1736835,
#     'entity1_id': 398019,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 6550,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 6,
#     'updated_at': '2020-11-14T18:22:01Z',
#     'start_date': '2008-01-15',
#     'end_date': '2012-08-14',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Barry Richard  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1736835',
#    'entity': 'https://littlesis.org/person/398019-Barry_Richard',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 970042,
#    'attributes': {'id': 970042,
#     'entity1_id': 201791,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 7450,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 10,
#     'updated_at': '2020-11-13T22:34:08Z',
#     'start_date': '2008-00-00',
#     'end_date': '2012-10-28',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'William F Ryan  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/970042',
#    'entity': 'https://littlesis.org/person/201791-William_F_Ryan',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 953884,
#    'attributes': {'id': 953884,
#     'entity1_id': 198071,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 7780,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 24,
#     'updated_at': '2020-11-13T22:28:16Z',
#     'start_date': '2008-00-00',
#     'end_date': '2012-10-18',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Linda Wray  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/953884',
#    'entity': 'https://littlesis.org/person/198071-Linda_Wray',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1736640,
#    'attributes': {'id': 1736640,
#     'entity1_id': 397969,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 2512,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 10,
#     'updated_at': '2020-11-13T17:50:45Z',
#     'start_date': '2011-09-29',
#     'end_date': '2012-10-19',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'David T Croall  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1736640',
#    'entity': 'https://littlesis.org/person/397969-David_T_Croall',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1736595,
#    'attributes': {'id': 1736595,
#     'entity1_id': 397968,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 6685,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 10,
#     'updated_at': '2020-11-13T17:44:55Z',
#     'start_date': '2007-06-08',
#     'end_date': '2012-09-02',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Kathleen M Brinkman  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1736595',
#    'entity': 'https://littlesis.org/person/397968-Kathleen_M_Brinkman',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1736489,
#    'attributes': {'id': 1736489,
#     'entity1_id': 397497,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 1000,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-11-12T16:33:18Z',
#     'start_date': '2012-02-09',
#     'end_date': '2012-02-09',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Mary Alice Haney  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1736489',
#    'entity': 'https://littlesis.org/person/397497-Mary_Alice_Haney',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1736386,
#    'attributes': {'id': 1736386,
#     'entity1_id': 397452,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 2300,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 2,
#     'updated_at': '2020-11-11T18:56:32Z',
#     'start_date': '2008-01-24',
#     'end_date': '2008-03-31',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Lawrence Noble  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1736386',
#    'entity': 'https://littlesis.org/person/397452-Lawrence_Noble',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1736307,
#    'attributes': {'id': 1736307,
#     'entity1_id': 397412,
#     'entity2_id': 13503,
#     'category_id': 1,
#     'description1': 'Steering committee member on Internet privacy',
#     'description2': None,
#     'amount': None,
#     'currency': None,
#     'goods': None,
#     'filings': None,
#     'updated_at': '2020-11-11T04:38:24Z',
#     'start_date': None,
#     'end_date': None,
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Mark Weinstein  had a position (Steering committee member on Internet privacy) at  Barack Obama ',
#     'category_attributes': {'is_board': True,
#      'is_executive': None,
#      'is_employee': None,
#      'compensation': None,
#      'boss_id': None}},
#    'self': 'https://littlesis.org/relationships/1736307',
#    'entity': 'https://littlesis.org/person/397412-Mark_Weinstein',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1736110,
#    'attributes': {'id': 1736110,
#     'entity1_id': 111243,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 250,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-11-10T14:28:50Z',
#     'start_date': '2012-10-27',
#     'end_date': '2012-10-27',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Catherine Eden  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1736110',
#    'entity': 'https://littlesis.org/person/111243-Catherine_Eden',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1736093,
#    'attributes': {'id': 1736093,
#     'entity1_id': 14087,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 1000,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-11-10T14:19:22Z',
#     'start_date': '2008-03-28',
#     'end_date': '2008-03-28',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Samuel G Coppersmith  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1736093',
#    'entity': 'https://littlesis.org/person/14087-Samuel_G_Coppersmith',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'},
#   {'type': 'relationships',
#    'id': 1736067,
#    'attributes': {'id': 1736067,
#     'entity1_id': 397343,
#     'entity2_id': 13503,
#     'category_id': 5,
#     'description1': 'Campaign Contribution',
#     'description2': 'Campaign Contribution',
#     'amount': 250,
#     'currency': 'usd',
#     'goods': None,
#     'filings': 1,
#     'updated_at': '2020-11-10T14:08:49Z',
#     'start_date': '2008-03-08',
#     'end_date': '2008-03-08',
#     'is_current': False,
#     'is_featured': False,
#     'description': 'Alfredo Gutierrez  gave money to  Barack Obama ',
#     'category_attributes': {'bundler_id': None}},
#    'self': 'https://littlesis.org/relationships/1736067',
#    'entity': 'https://littlesis.org/person/397343-Alfredo_Gutierrez',
#    'related': 'https://littlesis.org/person/13503-Barack_Obama'}]}

# %%
ls.relationships_df('Obama')
# Out:
#                                      primary_entity           related_entity  \
# 0                                      Barack Obama           Francis Rooney
# 1                                      Barack Obama            James E Risch
# 2                                      Barack Obama             Deborah Ross
# 3                                      Barack Obama          Andrew M Bursky
# 4                                      Barack Obama      Patricia Ann Woertz
# 5                                      Barack Obama         Mark E Goldhaber
# 6                                      Barack Obama          Melvyn J Estrin
# 7                                      Barack Obama             Greg Stanton
# 8                                      Barack Obama          Charles T Hagel
# 9                                      Barack Obama          Charles T Hagel
# 10                                     Barack Obama            Art J Gajarsa
# 11                                     Barack Obama                Tony West
# 12  President's Council on Jobs and Competitiveness             Barack Obama
# 13                                     Barack Obama         Kimmarie Sinatra
# 14                                     Barack Obama    John Jacob Rhodes III
# 15                                     Barack Obama        Louise M Sunshine
# 16                                     Barack Obama             Lisa E Davis
# 17                                     Barack Obama           Barry Weissler
# 18                                     Barack Obama            Paul Stockton
# 19                                     Barack Obama              Faye Fields
# 20                                     Barack Obama          Katrina Peebles
# 21                                     Barack Obama        R Donahue Peebles
# 22                                     Barack Obama         David M Marchick
# 23                                     Barack Obama             Gloria Getty
# 24                                     Barack Obama              Joel M Wine
# 25                                     Barack Obama         Raphael W Bostic
# 26                                     Barack Obama   Tillie Klearman Walton
# 27                                     Barack Obama      Sam Rawlings Walton
# 28                                     Barack Obama            Reuben Munger
# 29                                     Barack Obama                Sage Weil
# 30                                     Barack Obama           Merle Chambers
# 31                                     Barack Obama          David N Dinkins
# 32                                     Barack Obama             Tony Blinken
# 33                                     Barack Obama      Kenneth M Rosenberg
# 34                                     Barack Obama             Anthony Lake
# 35                                     Barack Obama           Kathy Boockvar
# 36                                     Barack Obama               Janet Yang
# 37                                     Barack Obama           Sharon Zackfia
# 38                                     Barack Obama  Melanie Franco Nussdorf
# 39                                     Barack Obama            Barry Richard
# 40                                     Barack Obama           William F Ryan
# 41                                     Barack Obama               Linda Wray
# 42                                     Barack Obama           David T Croall
# 43                                     Barack Obama      Kathleen M Brinkman
# 44                                     Barack Obama         Mary Alice Haney
# 45                                     Barack Obama           Lawrence Noble
# 46                                     Barack Obama           Mark Weinstein
# 47                                     Barack Obama           Catherine Eden
# 48                                     Barack Obama     Samuel G Coppersmith
# 49                                     Barack Obama        Alfredo Gutierrez
#
#    amount currency                                       category goods  \
# 0    3800      usd                          Campaign Contribution  None
# 1     281      usd                          Campaign Contribution  None
# 2     600      usd                          Campaign Contribution  None
# 3     250      usd                          Campaign Contribution  None
# 4    2250      usd                          Campaign Contribution  None
# 5    1000      usd                          Campaign Contribution  None
# 6    1350      usd                          Campaign Contribution  None
# 7     500      usd                          Campaign Contribution  None
# 8    2750      usd                          Campaign Contribution  None
# 9    None     None                              Defense Secretary  None
# 10    200      usd                          Campaign Contribution  None
# 11   2550      usd                          Campaign Contribution  None
# 12   None     None                                           None  None
# 13   1000      usd                          Campaign Contribution  None
# 14    250      usd                          Campaign Contribution  None
# 15   1250      usd                          Campaign Contribution  None
# 16   3250      usd                          Campaign Contribution  None
# 17   2300      usd                          Campaign Contribution  None
# 18    500      usd                          Campaign Contribution  None
# 19   4850      usd                          Campaign Contribution  None
# 20   2300      usd                          Campaign Contribution  None
# 21   2300      usd                          Campaign Contribution  None
# 22  -2100      usd                          Campaign Contribution  None
# 23   5000      usd                          Campaign Contribution  None
# 24    500      usd                          Campaign Contribution  None
# 30       8       Merle Chambers  gave money to  Barack Obama   2007-00-00
# 31       1      David N Dinkins  gave money to  Barack Obama   2012-03-30
# 32       2         Tony Blinken  gave money to  Barack Obama   2012-00-00
# 33       1  Kenneth M Rosenberg  gave money to  Barack Obama   2008-09-30
# 34    None  Anthony Lake  has/had a position (Foreign Poli...        None
# 35       1       Kathy Boockvar  gave money to  Barack Obama   2008-09-30
# 36       6           Janet Yang  gave money to  Barack Obama   2007-00-00
# 37       5       Sharon Zackfia  gave money to  Barack Obama   2007-09-19
# 38       1  Melanie Franco Nussdorf  gave money to  Barack...  2008-07-22
# 39       6        Barry Richard  gave money to  Barack Obama   2008-01-15
# 40      10       William F Ryan  gave money to  Barack Obama   2008-00-00
# 41      24           Linda Wray  gave money to  Barack Obama   2008-00-00
# 42      10       David T Croall  gave money to  Barack Obama   2011-09-29
# 43      10  Kathleen M Brinkman  gave money to  Barack Obama   2007-06-08
# 44       1     Mary Alice Haney  gave money to  Barack Obama   2012-02-09
# 45       2       Lawrence Noble  gave money to  Barack Obama   2008-01-24
# 46    None  Mark Weinstein  had a position (Steering commi...        None
# 47       1       Catherine Eden  gave money to  Barack Obama   2012-10-27
# 48       1  Samuel G Coppersmith  gave money to  Barack Ob...  2008-03-28
# 49       1    Alfredo Gutierrez  gave money to  Barack Obama   2008-03-08
#
#       end_date is_current
# 0   2012-10-26      False
# 1   2012-08-17      False
# 2   2008-08-31      False
# 3   2012-09-08      False
# 4   2012-06-15      False
# 5   2012-09-10      False
# 6   2012-08-21      False
# 7   2008-00-00       None
# 8   2012-03-06      False
# 9         None       None
# 10  2008-07-07      False
# 11  2007-05-18      False
# 12        None       None
# 13  2008-02-21      False
# 14  2008-03-05      False
# 15  2008-07-29      False
# 16  2012-07-25      False
# 17  2007-09-30      False
# 18  2012-07-31      False
# 19  2012-09-28      False
# 20  2008-01-18      False
# 21  2008-01-18      False
# 22  2012-00-00       None
# 23  2011-10-19      False
# 24  2011-11-25      False
# 25  2012-10-31      False
# 26  2012-04-10      False
# 27  2012-04-10      False
# 28  2011-05-02      False
# 29  2012-08-31      False
# 30  2012-09-21      False
# 31  2012-03-30      False
# 32  2012-11-03      False
# 33  2008-09-30      False
# 34        None       None
# 35  2008-09-30      False
# 36  2012-10-25      False
# 37  2012-04-20      False
# 38  2008-07-22      False
# 39  2012-08-14      False
# 40  2012-10-28      False
# 41  2012-10-18      False
# 42  2012-10-19      False
# 43  2012-09-02      False
# 44  2012-02-09      False
# 45  2008-03-31      False
# 46        None      False
# 47  2012-10-27      False
# 48  2008-03-28      False
# 49  2008-03-08      False

# %% [markdown]
# ### Get relationship timeline info by name input in dataframe

# %% [markdown]
# When the focus of analysis is more specifically the timeline of given relationships, timelines() is the function to use. It limits the columns included in the resulting data frame to entities related, start and end date, and if the relationship is current.

# %%
ls.timelines('Barack Obama')
# Out:
#                                     searched_entity           related_entity  \
# 0                                      Barack Obama           Francis Rooney
# 1                                      Barack Obama            James E Risch
# 2                                      Barack Obama             Deborah Ross
# 3                                      Barack Obama          Andrew M Bursky
# 4                                      Barack Obama      Patricia Ann Woertz
# 28  2008-00-00  2011-05-02      False
# 29  2008-09-04  2012-08-31      False
# 30  2007-00-00  2012-09-21      False
# 31  2012-03-30  2012-03-30      False
# 32  2012-00-00  2012-11-03      False
# 33  2008-09-30  2008-09-30      False
# 34        None        None       None
# 35  2008-09-30  2008-09-30      False
# 36  2007-00-00  2012-10-25      False
# 37  2007-09-19  2012-04-20      False
# 38  2008-07-22  2008-07-22      False
# 39  2008-01-15  2012-08-14      False
# 40  2008-00-00  2012-10-28      False
# 41  2008-00-00  2012-10-18      False
# 42  2011-09-29  2012-10-19      False
# 43  2007-06-08  2012-09-02      False
# 44  2012-02-09  2012-02-09      False
# 45  2008-01-24  2008-03-31      False
# 46        None        None      False
# 47  2012-10-27  2012-10-27      False
# 48  2008-03-28  2008-03-28      False
# 49  2008-03-08  2008-03-08      False

# %% [markdown]
# ### Get bio/background info by name input

# %% [markdown]
# Now comes a series of functions designed for exploratory analysis or the initial stages of research using the site. bio() outputs the biographical or background information included about a particular entity on a website. lists() notes all lists to which the given entity belongs, and lists_w_descriptions produces similar output but includes additional descriptors for each of the lists, if present in the database.

# %%
ls.bio('Barack Obama')
# Out:
# 'The 44th President of the United States, he was sworn into office on January 20, 2009; born in Honolulu, Hawaii, August 4, 1961; obtained early education in Jakarta, Indonesia, and Hawaii; continued education at Occidental College, Los Angeles, Calif.; received a B.A. in 1983 from Columbia University, New York City; worked as a community organizer in Chicago, Ill.; studied law at Harvard University, where he became the first African American president of the Harvard Law Review, and received J.D. in 1991; lecturer on constitutional law, University of Chicago; member, Illinois State senate 1997-2004; elected as a Democrat to the U.S. Senate in 2004 for term beginning January 3, 2005.'

# %% [markdown]
# ### Get list memberships for given named entity

# %%
ls.lists('Barack Obama')
# Out:
# Persons of Interest
# Featured Profiles
# GQ - Most Powerful People in DC
# Obama Administration Officials
# The Most Powerful People in Modern Healthcare, 2008
# All members of Congress since 1981
# Attendees of Ted Kennedy's funeral
# State Dinner Guest List, January 2011
# Obama Situation Room
# 100 Most Trusted People in America
# Robert Rubin's Network
# Time Magazine covers
# Obama White House bios - May 2014
# 100 Most Influential People in Healthcare (2014)
# 100 Most Powerful People in Finance (2014)
# Co-Sponsors of  Energy Diplomacy and Security Act of 2006
# Major African American Officer Holders
# 2016 Democratic Superdelegates
# The Attempted Coup

# %% [markdown]
# ### Get list memberships info plus extra descriptors of lists

# %%
ls.lists_w_descriptions('Barack Obama')
# Out:
# Persons of Interest (description: None )
# Featured Profiles (description: None )
# GQ - Most Powerful People in DC (description: None )
# Obama Administration Officials (description: Top officials in the incoming Obama administration )
# The Most Powerful People in Modern Healthcare, 2008 (description: None )
# All members of Congress since 1981 (description:  )
# Attendees of Ted Kennedy's funeral (description: None )
# State Dinner Guest List, January 2011 (description: The state dinner at the White House, honoring China's Hu Jintao. )
# Obama Situation Room (description: None )
# 100 Most Trusted People in America (description: Reader's Digest teamed up with research firm The Wagner Group to poll over 1,000 Americans and discover which individuals and the ideals they represent have earned our confidence.
# Published May 2013 )
# Robert Rubin's Network (description: None )
# Time Magazine covers (description: People featured on the US cover of Time Magazine. The year of the cover issue of Time follows the name. Those with multiple covers listed under most recent appearance.  )
# Obama White House bios - May 2014 (description: Snapshot of Obama White House blogger bios - June 2014 )
# 100 Most Influential People in Healthcare (2014) (description: Annual list published in Modern Healthcare August 2014.  )
# 100 Most Powerful People in Finance (2014) (description: Annual list compiled by Worth Magazine October 2014 )
# Co-Sponsors of  Energy Diplomacy and Security Act of 2006 (description: This is the bill that created the concept of the State Department's International Energy Coordinator job, which oversaw creation of the Global Shale Gas Initiative/Unconventional Gas Technical Engagement Program. )
# Major African American Officer Holders (description: Federal and State elected officers and US cabinet members "since 1641" Updated 2015 )
# 2016 Democratic Superdelegates (description: None )
# The Attempted Coup (description: The attempted takedown of POTUS )

# %% [markdown]
# ### Relationship descriptions for given named entity

# %% [markdown]
# Also likely useful for initial stages of research using the database, relationship_blurbs() outputs all of the short summaries of relationships for a given entity that are documented on the site. Quick read through of this list may suggest to researchers which relationships are of particular interest. relationships_blurbs_w_amounts() similarly produces a list of summarized relationships, but includes monetary amounts for relationships where money was involved. LittleSis is designed with the original goal to help researchers understand funding sources for policiticians and other influential people, these lists allow aid that goal of the site, and make these get requests much more efficient and understanding.

# %%
ls.relationship_blurbs('Obama')
# Out:
# Francis Rooney  gave money to  Barack Obama
# James E Risch  gave money to  Barack Obama
# Deborah Ross  gave money to  Barack Obama
# Andrew M Bursky  gave money to  Barack Obama
# Patricia Ann Woertz  gave money to  Barack Obama
# Mark E Goldhaber  gave money to  Barack Obama
# Melvyn J Estrin  gave money to  Barack Obama
# Greg Stanton  gave money to  Barack Obama
# Charles T Hagel  gave money to  Barack Obama
# Charles T Hagel  has/had a position (Defense Secretary) at  Barack Obama
# Art J Gajarsa  gave money to  Barack Obama
# Tony West  gave money to  Barack Obama
# Barack Obama  is/was an owner of  President's Council on Jobs and Competitiveness
# Kimmarie Sinatra  gave money to  Barack Obama
# John Jacob Rhodes III  gave money to  Barack Obama
# Louise M Sunshine  gave money to  Barack Obama
# Lisa E Davis  gave money to  Barack Obama
# Barry Weissler  gave money to  Barack Obama
# Paul Stockton  gave money to  Barack Obama
# Faye Fields  gave money to  Barack Obama
# Katrina Peebles  gave money to  Barack Obama
# R Donahue Peebles  gave money to  Barack Obama
# David M Marchick  gave money to  Barack Obama
# Gloria Getty  gave money to  Barack Obama
# Joel M Wine  gave money to  Barack Obama
# Raphael W Bostic  gave money to  Barack Obama
# Tillie Klearman Walton  gave money to  Barack Obama
# Sam Rawlings Walton  gave money to  Barack Obama
# Reuben Munger  gave money to  Barack Obama
# Sage Weil  gave money to  Barack Obama
# Merle Chambers  gave money to  Barack Obama
# David N Dinkins  gave money to  Barack Obama
# Tony Blinken  gave money to  Barack Obama
# Kenneth M Rosenberg  gave money to  Barack Obama
# Anthony Lake  has/had a position (Foreign Policy Advisor To) at  Barack Obama
# Kathy Boockvar  gave money to  Barack Obama
# Janet Yang  gave money to  Barack Obama
# Sharon Zackfia  gave money to  Barack Obama
# Melanie Franco Nussdorf  gave money to  Barack Obama
# Barry Richard  gave money to  Barack Obama
# William F Ryan  gave money to  Barack Obama
